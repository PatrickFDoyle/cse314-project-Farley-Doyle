# %%
import main as m

# %%
m.ReceptionByGenre("action")

# %%
m.ReceptionByGenre("rpg")

# %%
m.graphPlaytimeOfGenres()
# Out:
# [17.661696068349023, 17.997244941885494, 24.977653631284916, 10.292276316725557, 15.64570954211814, 14.47117085249381, 21.532251063460368, 14.17501527183873, 35.609172194981255, 35.339727550736725]
