# %%
import main as m
# Out:
# {'Valve': 10, 'Rockstar Games': 2, 'Ubisoft': 5, 'Bethesda Softworks': 6, 'Bohemia Interactive': 2, '2K': 4, 'Aspyr (Mac)': 5, 'Aspyr (Linux)': 3, 'Square Enix': 5, 'Feral Interactive (Linux)': 3, 'Feral Interactive (Mac)': 2, 'Paradox Interactive': 3, 'Tripwire Interactive': 2, 'Deep Silver': 2, 'The Behemoth': 2}
# None

# %%
m.ReceptionByGenre("Action")

# %%
m.ReceptionByGenre("rpg")

# %%
m.PublisherGraph()
# Out:
# {"['Valve']": 10, "['Rockstar Games']": 2, "['Ubisoft']": 5, "['Bethesda Softworks']": 6, "['Bohemia Interactive']": 2, "['2K', 'Aspyr (Mac)', 'Aspyr (Linux)']": 3, "['Square Enix', 'Feral Interactive (Mac)', 'Feral Interactive (Linux)']": 2, "['Paradox Interactive']": 3, "['Tripwire Interactive']": 2, "['Deep Silver']": 2, "['The Behemoth']": 2, "['Square Enix']": 2}
