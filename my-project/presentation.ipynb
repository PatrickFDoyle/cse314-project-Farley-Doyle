# %%
import main as m
# Out:
# {'Valve': 10, 'Rockstar Games': 2, 'Ubisoft': 5, 'Bethesda Softworks': 6, 'Bohemia Interactive': 2, '2K': 4, 'Aspyr ': 5, 'Square Enix': 5, 'Feral Interactive ': 3, 'Paradox Interactive': 3, 'Tripwire Interactive': 2, 'Deep Silver': 2, 'The Behemoth': 2}
# None
# Bad pipe message: %s [b'\xae\xca\xd8uw\xbdJ}\xa3\xbb?\xbc\x98-\x00\xcc\xfb\x91 \xc17\xa2\xef\x0c\xcd|\x9c\xc4\xa3\x9fSs\x1dH-a\xa15\xc6\x7f\xb8\xafO\x18\x0c\xb1\xca_\xc9\xa0*\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06']
# Bad pipe message: %s [b'\x05\x01\x06', b'']
# Bad pipe message: %s [b'\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x8c\xa9W\xe8\x8f\xa2\xfeAa\xe0N\x15\x93=\xc8\xe2q{\x17e\x9f\xd0']
# ...

# %%
m.GenresOfPublisher("Valve")

# %%
m.ReceptionByGenre("Action")

# %%
m.ReceptionByGenre("rpg")

# %%
m.PublisherGraph()
