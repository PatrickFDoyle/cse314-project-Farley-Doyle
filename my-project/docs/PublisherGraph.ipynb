# %%
import sys
sys.path.append("..")
import main as m
import pandas as pd

# %% [markdown]
# This function takes in nothing.
# It returns nothing and creates a bar graph illustrating how many games a publisher has published in the top, excluding those who have only published 1.
# Example

# %%
m.PublisherGraph()
