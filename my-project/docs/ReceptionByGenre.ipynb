# %%
import sys
sys.path.append("..")
import main as m
import pandas as pd

# %% [markdown]
# This function takes in one input. A string that is the name of the Genre. (Note this needs to be exactly how it appears on steam).
# It returns nothing, and creates a pie graph showing the sentiment of that genre on steam.
# Example

# %%
m.ReceptionByGenre("Action")
