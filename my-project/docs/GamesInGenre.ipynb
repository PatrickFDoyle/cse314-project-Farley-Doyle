# %%
import sys
sys.path.append("..")
import main as m

# %% [markdown]
# This function takes in one input. A string that is the name of the Genre. (Note this needs to be exactly how it appears on steam).
# It returns a dataframe that contains all games in that genre.
# Example

# %%
m.GamesInGenre("Action")
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   2000-11-01        1
# 1           20       Team Fortress Classic   1999-04-01        1
# 2           30               Day of Defeat   2003-05-01        1
# 3           40          Deathmatch Classic   2001-06-01        1
# 4           50   Half-Life: Opposing Force   1999-11-01        1
# ...        ...                         ...          ...      ...
# 27062  1062880  Scream of the Viking REDUX   2019-04-18        1
# 27063  1063060             MonteCube Dodge   2019-04-22        1
# 27065  1063560                    12 HOURS   2019-04-24        1
# 27071  1065570                   Cyber Gun   2019-04-23        1
# 27072  1065650            Super Star Blast   2019-04-24        1
#
#                   developer             publisher  \
# 0                 ['Valve']             ['Valve']
# 1                 ['Valve']             ['Valve']
# ...
