# %%
import sys
sys.path.append("..")
import main as m
import pandas as pd

# %% [markdown]
# This function takes in nothing.
# It returns a dataframe of the top 100 most reviewed on steam, which is an effective proxy for the top 100 most owned games on steam.
# Example

# %%
m.Top100()
# Out:
#         appid                                   name release_date  english  \
# 25        730       Counter-Strike: Global Offensive   2012-08-21        1
# 22        570                                 Dota 2   2013-07-09        1
# 12836  578080          PLAYERUNKNOWN'S BATTLEGROUNDS   2017-12-21        1
# 19        440                        Team Fortress 2   2007-10-10        1
# 2478   271590                     Grand Theft Auto V   2015-04-13        1
# ...       ...                                    ...          ...      ...
# 1325   208650                 Batman™: Arkham Knight   2015-06-23        1
# 3393   306130              The Elder Scrolls® Online   2017-05-22        1
# 2684   281990                              Stellaris   2016-05-09        1
# 1421   214950  Total War™: ROME II - Emperor Edition   2013-09-02        1
# 1154   113200                   The Binding of Isaac   2011-09-28        1
#
#                                     developer  \
# ...
